# %% [markdown]
# # Import Libraries

# %%
# !pip install -q pandas==2.0.3
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, f1_score


import warnings
warnings.simplefilter(action='ignore', category='PerformanceWarning')
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# mizani 0.11.1 requires pandas>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# plotnine 0.13.4 requires pandas<3.0.0,>=2.1.0, but you have pandas 2.0.3 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# xarray 2024.3.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
# !pip install -q BlackBoxAuditing 
# !pip install -q aif360
import aif360
from aif360.datasets import StandardDataset
from aif360.metrics import ClassificationMetric
# Out:
# 2024-05-14 23:12:31.614970: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-14 23:12:31.615119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-14 23:12:31.780507: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Prepare Dataset

# %%
train_df = pd.read_csv('/kaggle/input/ca-independent-medical-review/Independent_Medical_Review__IMR__Determinations__Trend.csv')
train_df = train_df[['Findings','Patient Gender','Age Range','Type']].dropna().reset_index(drop=True)
train_df['Type'] = train_df['Type'].map({'Urgent Care': 1,'Medical Necessity': 1,'Experimental/Investigational': 0})
train_df = train_df.sample(frac=1,random_state=42).reset_index(drop=True)
train_df
# Out:
#                                                 Findings Patient Gender  \
# 0      A male enrollee requested Harvoni 90/400 mg fo...           Male
# 1      A 31-year-old male enrollee has requested adul...           Male
# 2      A 60-year-old male enrollee has requested Soun...           Male
# 3      A 38-year-old male enrollee has requested arti...           Male
# 4      The patient is a 53-year-old female with right...         Female
# ...                                                  ...            ...
# 18010  A 59-year-old female enrollee has requested fo...         Female
# 18011  A 56-year-old female enrollee has requested co...         Female
# 18012  A 57-year-old female enrollee has requested ma...         Female
# 18013  Nature of Statutory Criteria/Case Summary:  An...           Male
# 18014  Physician 1: This patient is a 55-year-old mal...           Male
#
#       Age Range  Type
# 0         51-64     1
# 1         31-40     1
# 2         51-64     0
# 3         31-40     0
# 4         51-64     1
# ...         ...   ...
# 18010     51-64     1
# 18011     51-64     1
# 18012     51-64     1
# 18013     31-40     1
# 18014     51-64     0
#
# [18015 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
feats = ['Patient Gender','Age Range']
le = LabelEncoder()
for f in feats:
    le.fit(train_df[f].values.reshape(-1,))
    train_df[f] = le.transform(train_df[f].values.reshape(-1,))

# %%
CouVec = TfidfVectorizer(stop_words='english',max_features=50)
CouVec.fit(train_df['Findings'].values)
train_words = pd.DataFrame(CouVec.transform(train_df['Findings']).toarray())
train_words.shape
# Out:
# (18015, 50)

# %%
train_words = pd.concat([train_df[['Patient Gender','Age Range','Type']],train_words],axis=1).copy()
train_df = train_words
train_df.columns = train_df.columns.astype(str)

# %%
# DataFrame to store the metrics values
metrics_values = pd.DataFrame(columns=['Original','Corr','Expon','Grid','Thres'],index=range(2))

# %% [markdown]
# # Original Model

# %%
from sklearn.utils.extmath import softmax
from sklearn.linear_model import RidgeClassifier

class RidgeClassifierwithProba(RidgeClassifier):
    def predict_proba(self, X):
        d = self.decision_function(X)
        d_2d = np.c_[-d, d]
        return softmax(d_2d)
    
model = RidgeClassifierwithProba()

# %%
# CV and OOF Predictions

X = train_df.drop('Type',axis=1)
y = train_df['Type']

y_pred = pd.Series(0,index=X.index)

scores = []                   
for train_index, test_index in StratifiedKFold(n_splits=5).split(X, y):
    X_Train, X_Test = X.iloc[train_index,:], X.iloc[test_index,:]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]
    
    model.fit(X_Train.values,y_Train.values)

    preds = model.predict(X_Test.values)
    y_pred[test_index] = preds
    
    scores.append(f1_score(y_Test.values,preds))
    print(scores[-1])

print("Mean:",np.mean(scores),"\nSTD: ", np.std(scores),'\n')
# Out:
# 0.9798172124904798
# 0.9830894926847806
# 0.9834064466908259
# 0.9788692175899487
# 0.9817212490479817
# Mean: 0.9813807237008033
# STD:  0.0017827861809340511

# %% [markdown]
# # Metrics

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.03297033790725762
# Max Average Odds Difference (Ideal value = 0): 0.009108036651532987
# Max Equal Opportunity Difference (Ideal value = 0): 0.010906694715780985
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.1967133484268908
# Max Average Odds Difference (Ideal value = 0): 0.037805277305967736
# Max Equal Opportunity Difference (Ideal value = 0): 0.056533447407729476
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19795889853009152
# Max Average Odds Difference (Ideal value = 0): 0.060817638109360764
# Max Equal Opportunity Difference (Ideal value = 0): 0.1043470980854061
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832

# %% [markdown]
# # Mitigation Algorithms

# %% [markdown]
# # Preprocessing Algorithms:

# %% [markdown]
# ## 1- Reweighing

# %%
import pandas as pd
import numpy as np
from aif360.datasets import StandardDataset
from aif360.algorithms.preprocessing import Reweighing
from sklearn.model_selection import StratifiedKFold

X = train_df.drop('Type', axis=1)
y = train_df['Type']

y_pred_1 = pd.Series(0, index=X.index)

groups = [{'Patient Gender': 0, 'Age Range': i} for i in range(7)] + [{'Patient Gender': 1, 'Age Range': i} for i in range(7)]

scores = []
for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
    X_Train, X_Test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

    # Create a combined DataFrame for X_Train and y_Train
    combined_train = pd.concat([X_Train, y_Train], axis=1)

    # Convert to AIF360 format
    aif360_train = StandardDataset(combined_train,
                                   label_name='Type', favorable_classes=[1],
                                   protected_attribute_names=['Patient Gender', 'Age Range'],
                                   privileged_classes=[[1, i] for i in range(7)])

    # Apply the reweighing algorithm
    priv_group = [{'Patient Gender': 1, 'Age Range': i} for i in range(7)]
    unprivileged_groups = [{'Patient Gender': 0, 'Age Range': i} for i in range(7)]
    
    RW = Reweighing(unprivileged_groups=unprivileged_groups, privileged_groups=priv_group)
    aif360_train = RW.fit_transform(aif360_train)

    # Extract the weights and apply to the training data
    weights = aif360_train.instance_weights

    # Fit the model using the instance weights
    model.fit(X_Train, y_Train, sample_weight=weights)

    preds = model.predict(X_Test)
    y_pred_1[test_index] = preds

    scores.append(accuracy_score(y_Test.values, preds))
    print(scores[-1])

print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')
# Out:
# 0.9708576186511241
# 0.9744657230086039
# 0.9744657230086039
# 0.9691923397169026
# 0.9725228975853455
# Mean: 0.972300860394116
# STD:  0.0020575912287372233

# %%
y_pred_1.to_csv('y_pred_Reweighing.csv',index=False)

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_1

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.030485648507126595
# Max Average Odds Difference (Ideal value = 0): 0.01284546011288433
# Max Equal Opportunity Difference (Ideal value = 0): 0.01749179190915484
# Max Theil Index (Ideal value = 0): 0.01943477602976334
# Max Generalized Entropy Index (Ideal value = 0): 0.01386931899245455

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_1

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19710391960212628
# Max Average Odds Difference (Ideal value = 0): 0.04214954672067302
# Max Equal Opportunity Difference (Ideal value = 0): 0.06539525141950164
# Max Theil Index (Ideal value = 0): 0.01943477602976334
# Max Generalized Entropy Index (Ideal value = 0): 0.01386931899245455

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred_1

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19712611047465162
# Max Average Odds Difference (Ideal value = 0): 0.07358810932076318
# Max Equal Opportunity Difference (Ideal value = 0): 0.13004630591930533
# Max Theil Index (Ideal value = 0): 0.01943477602976334
# Max Generalized Entropy Index (Ideal value = 0): 0.01386931899245455

# %% [markdown]
# ## 2- Disparate Impact Remover

# %%
import pandas as pd
import numpy as np
from aif360.datasets import StandardDataset
from aif360.algorithms.preprocessing import DisparateImpactRemover
from sklearn.model_selection import StratifiedKFold

X = train_df.drop('Type', axis=1)
y = train_df['Type']

y_pred_2 = pd.Series(0, index=X.index)

scores = []
for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
    X_Train, X_Test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

    # Create a combined DataFrame for X_Train and y_Train
    combined_train = pd.concat([X_Train, y_Train], axis=1)

    # Convert to AIF360 format
    aif360_train = StandardDataset(combined_train,
                                   label_name='Type', favorable_classes=[1],
                                   protected_attribute_names=['Patient Gender', 'Age Range'],
                                   privileged_classes=[[1, i] for i in range(7)])

    # Apply the DisparateImpactRemover
    di_remover = DisparateImpactRemover(repair_level=1.0)
    aif360_train = di_remover.fit_transform(aif360_train)

    # Extract the transformed features and labels
    X_Train_transformed = aif360_train.features
    y_Train_transformed = aif360_train.labels.ravel()

    # Fit the model using the transformed data
    model.fit(X_Train_transformed, y_Train_transformed)

    # Transform the test set in the same way
    combined_test = pd.concat([X_Test, y_Test], axis=1)
    aif360_test = StandardDataset(combined_test,
                                  label_name='Type', favorable_classes=[1],
                                  protected_attribute_names=['Patient Gender', 'Age Range'],
                                  privileged_classes=[[1, i] for i in range(7)])
    aif360_test = di_remover.fit_transform(aif360_test)

    X_Test_transformed = aif360_test.features
    y_Test_transformed = aif360_test.labels.ravel()

    preds = model.predict(X_Test_transformed)
    y_pred_2[test_index] = preds

    scores.append(accuracy_score(y_Test_transformed, preds))
    print(scores[-1])

print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')
# Out:
# 0.9689147932278657
# 0.9744657230086039
# 0.9758534554537885
# 0.9675270607826811
# 0.9744657230086039
# Mean: 0.9722453510963087
# STD:  0.003353606986842776

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_2

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.03600398454988585
# Max Average Odds Difference (Ideal value = 0): 0.0028617153177400113
# Max Equal Opportunity Difference (Ideal value = 0): 0.0076186969926840264
# Max Theil Index (Ideal value = 0): 0.019419013745947955
# Max Generalized Entropy Index (Ideal value = 0): 0.013892589464757986

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_2

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.1972886031776003
# Max Average Odds Difference (Ideal value = 0): 0.04483817315098201
# Max Equal Opportunity Difference (Ideal value = 0): 0.07131519830945487
# Max Theil Index (Ideal value = 0): 0.019419013745947955
# Max Generalized Entropy Index (Ideal value = 0): 0.013892589464757986

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred_2

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.1981946147031162
# Max Average Odds Difference (Ideal value = 0): 0.0667227975818659
# Max Equal Opportunity Difference (Ideal value = 0): 0.11615741703041638
# Max Theil Index (Ideal value = 0): 0.019419013745947955
# Max Generalized Entropy Index (Ideal value = 0): 0.013892589464757986

# %% [markdown]
# ## 3- Learning Fair Representations (LFR)

# %%
# import pandas as pd
# import numpy as np
# from aif360.datasets import StandardDataset
# from aif360.algorithms.preprocessing import LFR
# from sklearn.model_selection import StratifiedKFold

# X = train_df.drop('Type', axis=1)
# y = train_df['Type']

# y_pred_3 = pd.Series(0, index=X.index)

# scores = []
# for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
#     X_Train, X_Test = X.iloc[train_index, :], X.iloc[test_index, :]
#     y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

#     # Create a combined DataFrame for X_Train and y_Train
#     combined_train = pd.concat([X_Train, y_Train], axis=1)

#     # Convert to AIF360 format
#     aif360_train = StandardDataset(combined_train,
#                                    label_name='Type', favorable_classes=[1],
#                                    protected_attribute_names=['Patient Gender', 'Age Range'],
#                                    privileged_classes=[[1, i] for i in range(7)])

#     # Apply the LFR algorithm
#     lfr = LFR(unprivileged_groups=[{'Patient Gender': 0}], privileged_groups=[{'Patient Gender': 1}],seed=42,k=4,verbose=0)
#     lfr.fit(aif360_train)
#     aif360_train_transformed = lfr.transform(aif360_train)

#     # Extract the transformed features and labels
#     X_Train_transformed = aif360_train_transformed.features
#     y_Train_transformed = aif360_train_transformed.labels.ravel()

#     # Fit the model using the transformed data
#     model.fit(X_Train_transformed, y_Train_transformed)

#     # Convert the test data to AIF360 format without the label
#     combined_test = X_Test.copy()
#     combined_test['Type'] = y_Test
#     aif360_test = StandardDataset(combined_test,
#                                   label_name='Type', favorable_classes=[1],
#                                   protected_attribute_names=['Patient Gender', 'Age Range'],
#                                   privileged_classes=[[1, i] for i in range(7)])

#     # Transform the test set using the LFR model fitted on the training set
#     aif360_test_transformed = lfr.transform(aif360_test)

#     X_Test_transformed = aif360_test_transformed.features

#     preds = model.predict(X_Test_transformed)
#     y_pred_3[test_index] = preds

#     scores.append(accuracy_score(y_Test.values, preds))
#     print(scores[-1])

# print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')

# %%
# y_pred_3.to_csv('y_pred_LFR.csv',index=False)

# %%
# import pandas as pd
# import numpy as np

# # Initialize variables to store maximum values of each metric
# max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

# for age_cls in range(2):
#     for priv_cls in [0,1]:
#         # Convert to AIF360 format
#         aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
#                                          label_name='Type', favorable_classes=[age_cls],
#                                          protected_attribute_names=['Patient Gender'],
#                                          privileged_classes=[[priv_cls]])

#         # Create a dataset for the predictions
#         aif360_pred_dataset = aif360_dataset.copy()
#         aif360_pred_dataset.labels = y_pred_3

#         import numpy as np

#         # Define the groups
#         groups = [
#             {'Patient Gender': 0},
#             {'Patient Gender': 1}
#         ]



#         # Iterate through the groups
#         for i, privileged_group in enumerate(groups):
#             # Define unprivileged groups as all other groups
#             unprivileged_groups = groups[:i] + groups[i+1:]

#             # Calculate metrics
#             metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
#                                           unprivileged_groups=unprivileged_groups,
#                                           privileged_groups=[privileged_group])

#             # Update maximum values
#             max_spd = max(max_spd, metric.statistical_parity_difference())
#             max_aod = max(max_aod, metric.average_odds_difference())
#             max_eod = max(max_eod, metric.equal_opportunity_difference())
#             max_theil = max(max_theil, metric.theil_index())
#             max_gei = max(max_gei, metric.generalized_entropy_index())
#             max_di = max(max_di, metric.disparate_impact())

# # Print maximum values
# print("Gender Bias Identification:")
# print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
# print("Max Average Odds Difference (Ideal value = 0):", max_aod)
# print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
# print("Max Theil Index (Ideal value = 0):", max_theil)
# print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)

# %%
# import pandas as pd
# import numpy as np

# # Initialize variables to store maximum values of each metric
# max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# # Find Max value for metrics by looping into all unique_values for the target and for the privileged class
# for age_cls in range(2):
#     for priv_cls in range(7):
#         # Convert to AIF360 format
#         aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
#                                          label_name='Type', favorable_classes=[age_cls],
#                                          protected_attribute_names=['Age Range'],
#                                          privileged_classes=[[priv_cls]])

#         # Create a dataset for the predictions
#         aif360_pred_dataset = aif360_dataset.copy()
#         aif360_pred_dataset.labels = y_pred_3

#         import numpy as np

#         # Define the groups
#         groups = [
#             {'Age Range': 0},
#             {'Age Range': 1},
#             {'Age Range': 2},
#             {'Age Range': 3},
#             {'Age Range': 4},
#             {'Age Range': 5},
#             {'Age Range': 6}]


#         # Iterate through the groups
#         for i, privileged_group in enumerate(groups):
#             # Define unprivileged groups as all other groups
#             unprivileged_groups = groups[:i] + groups[i+1:]

#             # Calculate metrics
#             metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
#                                           unprivileged_groups=unprivileged_groups,
#                                           privileged_groups=[privileged_group])

#             # Update maximum values
#             max_spd = max(max_spd, metric.statistical_parity_difference())
#             max_aod = max(max_aod, metric.average_odds_difference())
#             max_eod = max(max_eod, metric.equal_opportunity_difference())
#             max_theil = max(max_theil, metric.theil_index())
#             max_gei = max(max_gei, metric.generalized_entropy_index())
#             max_di = max(max_di, metric.disparate_impact())

# # Print maximum values
# print("Ethnicity Bias Identification:")
# print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
# print("Max Average Odds Difference (Ideal value = 0):", max_aod)
# print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
# print("Max Theil Index (Ideal value = 0):", max_theil)
# print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)

# %%
# import pandas as pd
# import numpy as np


# # Initialize variables to store maximum values of each metric
# max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# # Find Max value for metrics by looping into all unique_values for the target and for the privileged class
# for age_cls in range(2):
#     for priv_cls_1 in [0,1]:   # Gender        
#         for priv_cls_2 in range(7):   # Ethnicity

#             # Convert to AIF360 format
#             aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
#                                              label_name='Type', favorable_classes=[age_cls],
#                                              protected_attribute_names=['Patient Gender','Age Range'],
#                                              privileged_classes=[[priv_cls_1], [priv_cls_2]])

#             # Create a dataset for the predictions
#             aif360_pred_dataset = aif360_dataset.copy()
#             aif360_pred_dataset.labels = y_pred_3

#             import numpy as np

#             # Define the groups
#             groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

#             # Iterate through the groups
#             for i, privileged_group in enumerate(groups):
#                 # Define unprivileged groups as all other groups
#                 unprivileged_groups = groups[:i] + groups[i+1:]

#                 # Calculate metrics
#                 metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
#                                               unprivileged_groups=unprivileged_groups,
#                                               privileged_groups=[privileged_group])

#                 # Update maximum values
#                 max_spd = max(max_spd, metric.statistical_parity_difference())
#                 max_aod = max(max_aod, metric.average_odds_difference())
#                 max_eod = max(max_eod, metric.equal_opportunity_difference())
#                 max_theil = max(max_theil, metric.theil_index())
#                 max_gei = max(max_gei, metric.generalized_entropy_index())
#                 max_di = max(max_di, metric.disparate_impact())

# # Print maximum values
# print("Gender+Ethnicity Bias Identification:")
# print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
# print("Max Average Odds Difference (Ideal value = 0):", max_aod)
# print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
# print("Max Theil Index (Ideal value = 0):", max_theil)
# print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)

# %% [markdown]
# # In-processing Algorithms:

# %% [markdown]
# ## AdversarialDebiasing

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
import pandas as pd
import numpy as np
from aif360.datasets import StandardDataset
from aif360.algorithms.inprocessing import AdversarialDebiasing
from sklearn.model_selection import StratifiedKFold

# Function to convert dataframe to AIF360 StandardDataset
def convert_to_dataset(df, label_name, favorable_classes, protected_attribute_names, privileged_classes):
    return StandardDataset(df,
                           label_name=label_name,
                           favorable_classes=favorable_classes,
                           protected_attribute_names=protected_attribute_names,
                           privileged_classes=privileged_classes)

X = train_df.drop('Type', axis=1)
y = train_df['Type']

y_pred_4 = pd.Series(0, index=X.index)

scores = []

for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
    X_Train, X_Test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

    # Create a combined DataFrame for X_Train and y_Train
    combined_train = pd.concat([X_Train, y_Train], axis=1)

    # Convert to AIF360 format
    aif360_train = convert_to_dataset(combined_train,
                                      label_name='Type', favorable_classes=[1],
                                      protected_attribute_names=['Patient Gender', 'Age Range'],
                                      privileged_classes=[[1, i] for i in range(7)])

    # Apply the AdversarialDebiasing algorithm
    tf.reset_default_graph()
    sess = tf.Session()
    adv_debiasing = AdversarialDebiasing(privileged_groups=[{'Patient Gender': 1}],
                                         unprivileged_groups=[{'Patient Gender': 0}],
                                         scope_name='adv_debiasing',
                                         debias=True,
                                         sess=sess)
    adv_debiasing.fit(aif360_train)

    # Transform the training data
    aif360_train_pred = adv_debiasing.predict(aif360_train)
    X_Train_transformed = aif360_train_pred.features
    y_Train_transformed = aif360_train_pred.labels.ravel()

    # Train your model using the debiased training data
    model.fit(X_Train_transformed, y_Train_transformed)

    # Get predictions from your model
    preds = model.predict(X_Test.values)
    y_pred_4[test_index] = preds

    scores.append(accuracy_score(y_Test.values, preds))
    print(scores[-1])

sess.close()

print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')
# Out:
# epoch 0; iter: 0; batch classifier loss: 0.697595; batch adversarial loss: 0.709872
# epoch 1; iter: 0; batch classifier loss: 0.248158; batch adversarial loss: 0.721172
# epoch 2; iter: 0; batch classifier loss: 0.152113; batch adversarial loss: 0.690555
# epoch 3; iter: 0; batch classifier loss: 0.083501; batch adversarial loss: 0.698332
# epoch 4; iter: 0; batch classifier loss: 0.056352; batch adversarial loss: 0.690404
# epoch 5; iter: 0; batch classifier loss: 0.088809; batch adversarial loss: 0.708901
# epoch 6; iter: 0; batch classifier loss: 0.054993; batch adversarial loss: 0.704442
# epoch 7; iter: 0; batch classifier loss: 0.034658; batch adversarial loss: 0.673003
# epoch 8; iter: 0; batch classifier loss: 0.011596; batch adversarial loss: 0.675597
# epoch 9; iter: 0; batch classifier loss: 0.058036; batch adversarial loss: 0.688501
# epoch 10; iter: 0; batch classifier loss: 0.016414; batch adversarial loss: 0.691310
# epoch 11; iter: 0; batch classifier loss: 0.045363; batch adversarial loss: 0.658540
# epoch 12; iter: 0; batch classifier loss: 0.043854; batch adversarial loss: 0.684803
# epoch 13; iter: 0; batch classifier loss: 0.070068; batch adversarial loss: 0.690790
# epoch 14; iter: 0; batch classifier loss: 0.088552; batch adversarial loss: 0.682333
# epoch 15; iter: 0; batch classifier loss: 0.087798; batch adversarial loss: 0.678353
# epoch 16; iter: 0; batch classifier loss: 0.013747; batch adversarial loss: 0.668677
# epoch 17; iter: 0; batch classifier loss: 0.015779; batch adversarial loss: 0.672357
# epoch 18; iter: 0; batch classifier loss: 0.013513; batch adversarial loss: 0.661348
# epoch 19; iter: 0; batch classifier loss: 0.069681; batch adversarial loss: 0.674678
# epoch 20; iter: 0; batch classifier loss: 0.009181; batch adversarial loss: 0.677813
# epoch 21; iter: 0; batch classifier loss: 0.058704; batch adversarial loss: 0.663480
# epoch 22; iter: 0; batch classifier loss: 0.138551; batch adversarial loss: 0.669526
# epoch 23; iter: 0; batch classifier loss: 0.014198; batch adversarial loss: 0.691368
# epoch 24; iter: 0; batch classifier loss: 0.031686; batch adversarial loss: 0.695605
# epoch 25; iter: 0; batch classifier loss: 0.010813; batch adversarial loss: 0.670331
# epoch 26; iter: 0; batch classifier loss: 0.007680; batch adversarial loss: 0.676585
# epoch 27; iter: 0; batch classifier loss: 0.036928; batch adversarial loss: 0.672155
# epoch 28; iter: 0; batch classifier loss: 0.009078; batch adversarial loss: 0.689275
# epoch 29; iter: 0; batch classifier loss: 0.006501; batch adversarial loss: 0.658283
# epoch 30; iter: 0; batch classifier loss: 0.018051; batch adversarial loss: 0.699569
# epoch 31; iter: 0; batch classifier loss: 0.011619; batch adversarial loss: 0.669055
# epoch 32; iter: 0; batch classifier loss: 0.007792; batch adversarial loss: 0.670512
# epoch 33; iter: 0; batch classifier loss: 0.014515; batch adversarial loss: 0.681766
# epoch 34; iter: 0; batch classifier loss: 0.035945; batch adversarial loss: 0.671958
# epoch 35; iter: 0; batch classifier loss: 0.085969; batch adversarial loss: 0.703051
# epoch 36; iter: 0; batch classifier loss: 0.010978; batch adversarial loss: 0.684840
# epoch 37; iter: 0; batch classifier loss: 0.042912; batch adversarial loss: 0.697239
# epoch 38; iter: 0; batch classifier loss: 0.010337; batch adversarial loss: 0.691080
# epoch 39; iter: 0; batch classifier loss: 0.003550; batch adversarial loss: 0.691401
# epoch 40; iter: 0; batch classifier loss: 0.024552; batch adversarial loss: 0.666335
# epoch 41; iter: 0; batch classifier loss: 0.007832; batch adversarial loss: 0.683613
# epoch 42; iter: 0; batch classifier loss: 0.015402; batch adversarial loss: 0.702210
# epoch 43; iter: 0; batch classifier loss: 0.006516; batch adversarial loss: 0.660161
# epoch 44; iter: 0; batch classifier loss: 0.009456; batch adversarial loss: 0.660192
# epoch 45; iter: 0; batch classifier loss: 0.011621; batch adversarial loss: 0.697477
# epoch 46; iter: 0; batch classifier loss: 0.005657; batch adversarial loss: 0.673999
# epoch 47; iter: 0; batch classifier loss: 0.020350; batch adversarial loss: 0.692945
# epoch 48; iter: 0; batch classifier loss: 0.013447; batch adversarial loss: 0.683594
# epoch 49; iter: 0; batch classifier loss: 0.004729; batch adversarial loss: 0.696417
# 0.9708576186511241
# epoch 0; iter: 0; batch classifier loss: 0.720302; batch adversarial loss: 0.661014
# epoch 1; iter: 0; batch classifier loss: 0.201054; batch adversarial loss: 0.699306
# epoch 2; iter: 0; batch classifier loss: 0.155743; batch adversarial loss: 0.685526
# epoch 3; iter: 0; batch classifier loss: 0.089203; batch adversarial loss: 0.699012
# epoch 4; iter: 0; batch classifier loss: 0.029648; batch adversarial loss: 0.672864
# epoch 5; iter: 0; batch classifier loss: 0.016141; batch adversarial loss: 0.696399
# epoch 6; iter: 0; batch classifier loss: 0.085354; batch adversarial loss: 0.674630
# epoch 7; iter: 0; batch classifier loss: 0.038598; batch adversarial loss: 0.676443
# epoch 8; iter: 0; batch classifier loss: 0.015614; batch adversarial loss: 0.687521
# epoch 9; iter: 0; batch classifier loss: 0.012939; batch adversarial loss: 0.696085
# epoch 10; iter: 0; batch classifier loss: 0.018375; batch adversarial loss: 0.685598
# epoch 11; iter: 0; batch classifier loss: 0.028448; batch adversarial loss: 0.672278
# epoch 12; iter: 0; batch classifier loss: 0.023834; batch adversarial loss: 0.677422
# epoch 13; iter: 0; batch classifier loss: 0.113619; batch adversarial loss: 0.678963
# epoch 14; iter: 0; batch classifier loss: 0.011855; batch adversarial loss: 0.667577
# epoch 15; iter: 0; batch classifier loss: 0.015218; batch adversarial loss: 0.706501
# epoch 16; iter: 0; batch classifier loss: 0.038690; batch adversarial loss: 0.669786
# epoch 17; iter: 0; batch classifier loss: 0.081207; batch adversarial loss: 0.677361
# epoch 18; iter: 0; batch classifier loss: 0.067237; batch adversarial loss: 0.674344
# epoch 19; iter: 0; batch classifier loss: 0.009150; batch adversarial loss: 0.673206
# epoch 20; iter: 0; batch classifier loss: 0.017616; batch adversarial loss: 0.694097
# epoch 21; iter: 0; batch classifier loss: 0.067877; batch adversarial loss: 0.692106
# epoch 22; iter: 0; batch classifier loss: 0.019104; batch adversarial loss: 0.685012
# epoch 23; iter: 0; batch classifier loss: 0.025114; batch adversarial loss: 0.656684
# epoch 24; iter: 0; batch classifier loss: 0.015159; batch adversarial loss: 0.701501
# epoch 25; iter: 0; batch classifier loss: 0.025339; batch adversarial loss: 0.678724
# epoch 26; iter: 0; batch classifier loss: 0.016527; batch adversarial loss: 0.656819
# epoch 27; iter: 0; batch classifier loss: 0.005281; batch adversarial loss: 0.688726
# epoch 28; iter: 0; batch classifier loss: 0.017436; batch adversarial loss: 0.675931
# epoch 29; iter: 0; batch classifier loss: 0.007063; batch adversarial loss: 0.675131
# epoch 30; iter: 0; batch classifier loss: 0.010769; batch adversarial loss: 0.693790
# epoch 31; iter: 0; batch classifier loss: 0.003983; batch adversarial loss: 0.668259
# epoch 32; iter: 0; batch classifier loss: 0.068302; batch adversarial loss: 0.666916
# epoch 33; iter: 0; batch classifier loss: 0.065664; batch adversarial loss: 0.682455
# epoch 34; iter: 0; batch classifier loss: 0.018354; batch adversarial loss: 0.714671
# epoch 35; iter: 0; batch classifier loss: 0.010403; batch adversarial loss: 0.688928
# epoch 36; iter: 0; batch classifier loss: 0.027308; batch adversarial loss: 0.707242
# epoch 37; iter: 0; batch classifier loss: 0.005633; batch adversarial loss: 0.691829
# epoch 38; iter: 0; batch classifier loss: 0.034154; batch adversarial loss: 0.699032
# epoch 39; iter: 0; batch classifier loss: 0.006727; batch adversarial loss: 0.692728
# epoch 40; iter: 0; batch classifier loss: 0.021998; batch adversarial loss: 0.688173
# epoch 41; iter: 0; batch classifier loss: 0.004133; batch adversarial loss: 0.684999
# epoch 42; iter: 0; batch classifier loss: 0.018107; batch adversarial loss: 0.689397
# epoch 43; iter: 0; batch classifier loss: 0.014014; batch adversarial loss: 0.680599
# epoch 44; iter: 0; batch classifier loss: 0.046870; batch adversarial loss: 0.657092
# epoch 45; iter: 0; batch classifier loss: 0.033750; batch adversarial loss: 0.666615
# epoch 46; iter: 0; batch classifier loss: 0.002896; batch adversarial loss: 0.672080
# epoch 47; iter: 0; batch classifier loss: 0.005470; batch adversarial loss: 0.692459
# epoch 48; iter: 0; batch classifier loss: 0.088726; batch adversarial loss: 0.673024
# epoch 49; iter: 0; batch classifier loss: 0.019095; batch adversarial loss: 0.678388
# 0.9744657230086039
# epoch 0; iter: 0; batch classifier loss: 0.671185; batch adversarial loss: 0.781235
# epoch 1; iter: 0; batch classifier loss: 0.272980; batch adversarial loss: 0.793542
# epoch 2; iter: 0; batch classifier loss: 0.149087; batch adversarial loss: 0.776034
# epoch 3; iter: 0; batch classifier loss: 0.090179; batch adversarial loss: 0.730995
# epoch 4; iter: 0; batch classifier loss: 0.060737; batch adversarial loss: 0.717228
# epoch 5; iter: 0; batch classifier loss: 0.044243; batch adversarial loss: 0.695182
# epoch 6; iter: 0; batch classifier loss: 0.056985; batch adversarial loss: 0.663799
# epoch 7; iter: 0; batch classifier loss: 0.015032; batch adversarial loss: 0.678673
# epoch 8; iter: 0; batch classifier loss: 0.016103; batch adversarial loss: 0.676168
# epoch 9; iter: 0; batch classifier loss: 0.039005; batch adversarial loss: 0.676310
# epoch 10; iter: 0; batch classifier loss: 0.013237; batch adversarial loss: 0.670926
# epoch 11; iter: 0; batch classifier loss: 0.039553; batch adversarial loss: 0.673803
# epoch 12; iter: 0; batch classifier loss: 0.021810; batch adversarial loss: 0.683155
# epoch 13; iter: 0; batch classifier loss: 0.007671; batch adversarial loss: 0.692688
# epoch 14; iter: 0; batch classifier loss: 0.017977; batch adversarial loss: 0.684045
# epoch 15; iter: 0; batch classifier loss: 0.073111; batch adversarial loss: 0.689331
# epoch 16; iter: 0; batch classifier loss: 0.045932; batch adversarial loss: 0.684422
# epoch 17; iter: 0; batch classifier loss: 0.007452; batch adversarial loss: 0.660043
# epoch 18; iter: 0; batch classifier loss: 0.005539; batch adversarial loss: 0.696214
# epoch 19; iter: 0; batch classifier loss: 0.010417; batch adversarial loss: 0.669614
# epoch 20; iter: 0; batch classifier loss: 0.044636; batch adversarial loss: 0.692323
# epoch 21; iter: 0; batch classifier loss: 0.011186; batch adversarial loss: 0.683932
# epoch 22; iter: 0; batch classifier loss: 0.037130; batch adversarial loss: 0.667273
# epoch 23; iter: 0; batch classifier loss: 0.008947; batch adversarial loss: 0.682324
# epoch 24; iter: 0; batch classifier loss: 0.040729; batch adversarial loss: 0.687026
# epoch 25; iter: 0; batch classifier loss: 0.027449; batch adversarial loss: 0.699601
# epoch 26; iter: 0; batch classifier loss: 0.005931; batch adversarial loss: 0.682180
# epoch 27; iter: 0; batch classifier loss: 0.010000; batch adversarial loss: 0.687993
# epoch 28; iter: 0; batch classifier loss: 0.077845; batch adversarial loss: 0.673925
# epoch 29; iter: 0; batch classifier loss: 0.008846; batch adversarial loss: 0.674752
# epoch 30; iter: 0; batch classifier loss: 0.013024; batch adversarial loss: 0.705584
# epoch 31; iter: 0; batch classifier loss: 0.003993; batch adversarial loss: 0.686386
# epoch 32; iter: 0; batch classifier loss: 0.006606; batch adversarial loss: 0.710635
# epoch 33; iter: 0; batch classifier loss: 0.011081; batch adversarial loss: 0.671414
# epoch 34; iter: 0; batch classifier loss: 0.003218; batch adversarial loss: 0.662499
# epoch 35; iter: 0; batch classifier loss: 0.007151; batch adversarial loss: 0.666863
# epoch 36; iter: 0; batch classifier loss: 0.004346; batch adversarial loss: 0.696663
# epoch 37; iter: 0; batch classifier loss: 0.036710; batch adversarial loss: 0.697510
# epoch 38; iter: 0; batch classifier loss: 0.028509; batch adversarial loss: 0.680828
# epoch 39; iter: 0; batch classifier loss: 0.020306; batch adversarial loss: 0.674256
# epoch 40; iter: 0; batch classifier loss: 0.006024; batch adversarial loss: 0.702883
# epoch 41; iter: 0; batch classifier loss: 0.008326; batch adversarial loss: 0.703273
# epoch 42; iter: 0; batch classifier loss: 0.003493; batch adversarial loss: 0.691190
# epoch 43; iter: 0; batch classifier loss: 0.004864; batch adversarial loss: 0.697927
# epoch 44; iter: 0; batch classifier loss: 0.008092; batch adversarial loss: 0.670536
# epoch 45; iter: 0; batch classifier loss: 0.014329; batch adversarial loss: 0.666595
# epoch 46; iter: 0; batch classifier loss: 0.007999; batch adversarial loss: 0.675530
# epoch 47; iter: 0; batch classifier loss: 0.034119; batch adversarial loss: 0.657879
# epoch 48; iter: 0; batch classifier loss: 0.075186; batch adversarial loss: 0.658424
# epoch 49; iter: 0; batch classifier loss: 0.010013; batch adversarial loss: 0.688434
# 0.9752983624757147
# epoch 0; iter: 0; batch classifier loss: 0.817162; batch adversarial loss: 0.675758
# epoch 1; iter: 0; batch classifier loss: 0.269045; batch adversarial loss: 0.696061
# epoch 2; iter: 0; batch classifier loss: 0.106182; batch adversarial loss: 0.692303
# epoch 3; iter: 0; batch classifier loss: 0.079717; batch adversarial loss: 0.681704
# epoch 4; iter: 0; batch classifier loss: 0.062195; batch adversarial loss: 0.673600
# epoch 5; iter: 0; batch classifier loss: 0.109605; batch adversarial loss: 0.695924
# epoch 6; iter: 0; batch classifier loss: 0.051630; batch adversarial loss: 0.691134
# epoch 7; iter: 0; batch classifier loss: 0.049243; batch adversarial loss: 0.696242
# epoch 8; iter: 0; batch classifier loss: 0.035609; batch adversarial loss: 0.696481
# epoch 9; iter: 0; batch classifier loss: 0.076047; batch adversarial loss: 0.674435
# epoch 10; iter: 0; batch classifier loss: 0.060006; batch adversarial loss: 0.665505
# epoch 11; iter: 0; batch classifier loss: 0.024046; batch adversarial loss: 0.698878
# epoch 12; iter: 0; batch classifier loss: 0.010368; batch adversarial loss: 0.689975
# epoch 13; iter: 0; batch classifier loss: 0.014141; batch adversarial loss: 0.668362
# epoch 14; iter: 0; batch classifier loss: 0.015900; batch adversarial loss: 0.686379
# epoch 15; iter: 0; batch classifier loss: 0.055309; batch adversarial loss: 0.701310
# epoch 16; iter: 0; batch classifier loss: 0.029477; batch adversarial loss: 0.671615
# epoch 17; iter: 0; batch classifier loss: 0.069279; batch adversarial loss: 0.676710
# epoch 18; iter: 0; batch classifier loss: 0.043085; batch adversarial loss: 0.681794
# epoch 19; iter: 0; batch classifier loss: 0.029148; batch adversarial loss: 0.667304
# epoch 20; iter: 0; batch classifier loss: 0.045626; batch adversarial loss: 0.682484
# epoch 21; iter: 0; batch classifier loss: 0.007612; batch adversarial loss: 0.686599
# epoch 22; iter: 0; batch classifier loss: 0.032376; batch adversarial loss: 0.688184
# epoch 23; iter: 0; batch classifier loss: 0.035042; batch adversarial loss: 0.669910
# epoch 24; iter: 0; batch classifier loss: 0.063068; batch adversarial loss: 0.674033
# epoch 25; iter: 0; batch classifier loss: 0.006581; batch adversarial loss: 0.663506
# epoch 26; iter: 0; batch classifier loss: 0.032251; batch adversarial loss: 0.679835
# epoch 27; iter: 0; batch classifier loss: 0.004224; batch adversarial loss: 0.691661
# epoch 28; iter: 0; batch classifier loss: 0.004893; batch adversarial loss: 0.682472
# epoch 29; iter: 0; batch classifier loss: 0.005363; batch adversarial loss: 0.664121
# epoch 30; iter: 0; batch classifier loss: 0.003760; batch adversarial loss: 0.699863
# epoch 31; iter: 0; batch classifier loss: 0.051798; batch adversarial loss: 0.672427
# epoch 32; iter: 0; batch classifier loss: 0.009613; batch adversarial loss: 0.685787
# epoch 33; iter: 0; batch classifier loss: 0.037296; batch adversarial loss: 0.689879
# epoch 34; iter: 0; batch classifier loss: 0.024307; batch adversarial loss: 0.664654
# epoch 35; iter: 0; batch classifier loss: 0.003955; batch adversarial loss: 0.687866
# epoch 36; iter: 0; batch classifier loss: 0.055751; batch adversarial loss: 0.673574
# epoch 37; iter: 0; batch classifier loss: 0.005789; batch adversarial loss: 0.669441
# epoch 38; iter: 0; batch classifier loss: 0.009135; batch adversarial loss: 0.690111
# epoch 39; iter: 0; batch classifier loss: 0.007217; batch adversarial loss: 0.689130
# epoch 40; iter: 0; batch classifier loss: 0.033132; batch adversarial loss: 0.661906
# epoch 41; iter: 0; batch classifier loss: 0.060479; batch adversarial loss: 0.665139
# epoch 42; iter: 0; batch classifier loss: 0.012696; batch adversarial loss: 0.708116
# epoch 43; iter: 0; batch classifier loss: 0.044575; batch adversarial loss: 0.669678
# epoch 44; iter: 0; batch classifier loss: 0.018580; batch adversarial loss: 0.670086
# epoch 45; iter: 0; batch classifier loss: 0.004150; batch adversarial loss: 0.686440
# epoch 46; iter: 0; batch classifier loss: 0.004752; batch adversarial loss: 0.690736
# epoch 47; iter: 0; batch classifier loss: 0.012560; batch adversarial loss: 0.687118
# epoch 48; iter: 0; batch classifier loss: 0.023944; batch adversarial loss: 0.664878
# epoch 49; iter: 0; batch classifier loss: 0.013066; batch adversarial loss: 0.689761
# 0.9694698862059395
# epoch 0; iter: 0; batch classifier loss: 0.680511; batch adversarial loss: 0.728746
# epoch 1; iter: 0; batch classifier loss: 0.253034; batch adversarial loss: 0.709058
# epoch 2; iter: 0; batch classifier loss: 0.118542; batch adversarial loss: 0.717013
# epoch 3; iter: 0; batch classifier loss: 0.135440; batch adversarial loss: 0.742236
# epoch 4; iter: 0; batch classifier loss: 0.096874; batch adversarial loss: 0.652736
# epoch 5; iter: 0; batch classifier loss: 0.037715; batch adversarial loss: 0.691490
# epoch 6; iter: 0; batch classifier loss: 0.070127; batch adversarial loss: 0.695774
# epoch 7; iter: 0; batch classifier loss: 0.030865; batch adversarial loss: 0.689347
# epoch 8; iter: 0; batch classifier loss: 0.018360; batch adversarial loss: 0.689621
# epoch 9; iter: 0; batch classifier loss: 0.013825; batch adversarial loss: 0.691593
# epoch 10; iter: 0; batch classifier loss: 0.048518; batch adversarial loss: 0.676023
# epoch 11; iter: 0; batch classifier loss: 0.025008; batch adversarial loss: 0.674767
# epoch 12; iter: 0; batch classifier loss: 0.076557; batch adversarial loss: 0.682135
# epoch 13; iter: 0; batch classifier loss: 0.015141; batch adversarial loss: 0.697170
# epoch 14; iter: 0; batch classifier loss: 0.045968; batch adversarial loss: 0.697734
# epoch 15; iter: 0; batch classifier loss: 0.054361; batch adversarial loss: 0.667647
# epoch 16; iter: 0; batch classifier loss: 0.038968; batch adversarial loss: 0.703038
# epoch 17; iter: 0; batch classifier loss: 0.019052; batch adversarial loss: 0.705950
# epoch 18; iter: 0; batch classifier loss: 0.007556; batch adversarial loss: 0.674540
# epoch 19; iter: 0; batch classifier loss: 0.011887; batch adversarial loss: 0.672640
# epoch 20; iter: 0; batch classifier loss: 0.008340; batch adversarial loss: 0.676960
# epoch 21; iter: 0; batch classifier loss: 0.018406; batch adversarial loss: 0.677982
# epoch 22; iter: 0; batch classifier loss: 0.013225; batch adversarial loss: 0.679647
# epoch 23; iter: 0; batch classifier loss: 0.027107; batch adversarial loss: 0.682227
# epoch 24; iter: 0; batch classifier loss: 0.015990; batch adversarial loss: 0.671156
# epoch 25; iter: 0; batch classifier loss: 0.046012; batch adversarial loss: 0.684791
# epoch 26; iter: 0; batch classifier loss: 0.007699; batch adversarial loss: 0.665171
# epoch 27; iter: 0; batch classifier loss: 0.011429; batch adversarial loss: 0.673157
# epoch 28; iter: 0; batch classifier loss: 0.034774; batch adversarial loss: 0.655634
# epoch 29; iter: 0; batch classifier loss: 0.027468; batch adversarial loss: 0.678885
# epoch 30; iter: 0; batch classifier loss: 0.056769; batch adversarial loss: 0.671479
# epoch 31; iter: 0; batch classifier loss: 0.006776; batch adversarial loss: 0.704636
# epoch 32; iter: 0; batch classifier loss: 0.007645; batch adversarial loss: 0.673524
# epoch 33; iter: 0; batch classifier loss: 0.023895; batch adversarial loss: 0.699926
# epoch 34; iter: 0; batch classifier loss: 0.019694; batch adversarial loss: 0.709918
# epoch 35; iter: 0; batch classifier loss: 0.008257; batch adversarial loss: 0.689999
# epoch 36; iter: 0; batch classifier loss: 0.061323; batch adversarial loss: 0.704052
# epoch 37; iter: 0; batch classifier loss: 0.004070; batch adversarial loss: 0.688817
# epoch 38; iter: 0; batch classifier loss: 0.021693; batch adversarial loss: 0.678881
# epoch 39; iter: 0; batch classifier loss: 0.005995; batch adversarial loss: 0.685453
# epoch 40; iter: 0; batch classifier loss: 0.021794; batch adversarial loss: 0.682699
# epoch 41; iter: 0; batch classifier loss: 0.057790; batch adversarial loss: 0.671102
# epoch 42; iter: 0; batch classifier loss: 0.022191; batch adversarial loss: 0.645489
# epoch 43; iter: 0; batch classifier loss: 0.004158; batch adversarial loss: 0.678197
# epoch 44; iter: 0; batch classifier loss: 0.004979; batch adversarial loss: 0.671093
# epoch 45; iter: 0; batch classifier loss: 0.004250; batch adversarial loss: 0.677982
# epoch 46; iter: 0; batch classifier loss: 0.033046; batch adversarial loss: 0.690617
# epoch 47; iter: 0; batch classifier loss: 0.011252; batch adversarial loss: 0.664065
# epoch 48; iter: 0; batch classifier loss: 0.015288; batch adversarial loss: 0.654923
# epoch 49; iter: 0; batch classifier loss: 0.016217; batch adversarial loss: 0.672289
# 0.9728004440743825
# Mean: 0.972578406883153
# STD:  0.002174094479885194

# %%
y_pred_4.to_csv('y_pred_AD.csv',index=False)

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_4

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.03247258470046133
# Max Average Odds Difference (Ideal value = 0): 0.009786128684587711
# Max Equal Opportunity Difference (Ideal value = 0): 0.01197450037515102
# Max Theil Index (Ideal value = 0): 0.01918802884823289
# Max Generalized Entropy Index (Ideal value = 0): 0.013725876540357411

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_4

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19726739915331287
# Max Average Odds Difference (Ideal value = 0): 0.0408168455630907
# Max Equal Opportunity Difference (Ideal value = 0): 0.06266611499540664
# Max Theil Index (Ideal value = 0): 0.01918802884823289
# Max Generalized Entropy Index (Ideal value = 0): 0.013725876540357411

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred_4

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19760421263486116
# Max Average Odds Difference (Ideal value = 0): 0.06835083251480223
# Max Equal Opportunity Difference (Ideal value = 0): 0.11885955795745862
# Max Theil Index (Ideal value = 0): 0.01918802884823289
# Max Generalized Entropy Index (Ideal value = 0): 0.013725876540357411

# %% [markdown]
# # Postprocessing Algorithms:

# %% [markdown]
# ## 1- Equalized Odds Postprocessing

# %%
import pandas as pd
import numpy as np
from aif360.datasets import StandardDataset
from aif360.algorithms.postprocessing import CalibratedEqOddsPostprocessing
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# Function to convert dataframe to AIF360 StandardDataset
def convert_to_dataset(df, label_name, favorable_classes, protected_attribute_names, privileged_classes):
    return StandardDataset(df,
                           label_name=label_name,
                           favorable_classes=favorable_classes,
                           protected_attribute_names=protected_attribute_names,
                           privileged_classes=privileged_classes)

# Preprocessing the data
X = train_df.drop('Type', axis=1)
y = train_df['Type']

y_pred_5 = pd.Series(0, index=X.index)

scores = []

for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
    X_Train, X_Test = X.values[train_index], X.values[test_index]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

    # Train your model on the original data
    model.fit(X_Train, y_Train)
    
    # Make predictions on the training and test sets
    y_train_pred = model.predict(X_Train)
    y_test_pred = model.predict(X_Test)
    
    # Combine predictions with training data
    combined_train = pd.DataFrame(X_Train, columns=X.columns)
    combined_train['Type'] = y_Train.values
    combined_train['pred'] = y_train_pred

    # Convert to AIF360 format for the training set
    aif360_train = convert_to_dataset(combined_train,
                                      label_name='Type', favorable_classes=[1],
                                      protected_attribute_names=['Patient Gender'],
                                      privileged_classes=[[1]])
    
    # Convert to AIF360 format for the predicted training set
    combined_train_pred = combined_train.copy()
    combined_train_pred['Type'] = combined_train['pred']
    aif360_train_pred = convert_to_dataset(combined_train_pred,
                                           label_name='Type', favorable_classes=[1],
                                           protected_attribute_names=['Patient Gender'],
                                           privileged_classes=[[1]])
    
    # Apply Calibrated Equalized Odds Postprocessing using only the training set
    cpp = CalibratedEqOddsPostprocessing(privileged_groups=[{'Patient Gender': 1}],
                                         unprivileged_groups=[{'Patient Gender': 0}],
                                         cost_constraint="weighted")
    cpp = cpp.fit(aif360_train, aif360_train_pred)
    
    # Apply the post-processing to the test predictions
    combined_test = pd.DataFrame(X_Test, columns=X.columns)
    combined_test['pred'] = y_test_pred
    aif360_test_pred = convert_to_dataset(combined_test,
                                          label_name='pred', favorable_classes=[1],
                                          protected_attribute_names=['Patient Gender'],
                                          privileged_classes=[[1]])
    
    aif360_test_pred = cpp.predict(aif360_test_pred)
    
    # Get the final predictions
    preds = aif360_test_pred.labels.ravel()
    y_pred_5[test_index] = preds

    scores.append(accuracy_score(y_Test.values, preds))
    print(scores[-1])

print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')
# Out:
# 0.9703025256730502
# 0.9752983624757147
# 0.9747432694976409
# 0.9680821537607549
# 0.9733555370524563
# Mean: 0.9723563696919234
# STD:  0.0027509323770999565

# %%
y_pred_5.to_csv('y_pred_EOP.csv',index=False)

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_5

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.03213869198060243
# Max Average Odds Difference (Ideal value = 0): 0.010403880077618832
# Max Equal Opportunity Difference (Ideal value = 0): 0.01336282510868736
# Max Theil Index (Ideal value = 0): 0.019342018780042932
# Max Generalized Entropy Index (Ideal value = 0): 0.013837018489957793

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_5

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19603617531681944
# Max Average Odds Difference (Ideal value = 0): 0.03669835752175789
# Max Equal Opportunity Difference (Ideal value = 0): 0.05440624043049058
# Max Theil Index (Ideal value = 0): 0.019342018780042932
# Max Generalized Entropy Index (Ideal value = 0): 0.013837018489957793

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred_5

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19730456505796018
# Max Average Odds Difference (Ideal value = 0): 0.05973878678464788
# Max Equal Opportunity Difference (Ideal value = 0): 0.10226852814152754
# Max Theil Index (Ideal value = 0): 0.019342018780042932
# Max Generalized Entropy Index (Ideal value = 0): 0.013837018489957793

# %% [markdown]
# ## 2- Reject Option Classification

# %%
import pandas as pd
import numpy as np
from aif360.datasets import StandardDataset
from aif360.algorithms.postprocessing import RejectOptionClassification
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# Function to convert dataframe to AIF360 StandardDataset
def convert_to_dataset(df, label_name, favorable_classes, protected_attribute_names, privileged_classes):
    return StandardDataset(df,
                           label_name=label_name,
                           favorable_classes=favorable_classes,
                           protected_attribute_names=protected_attribute_names,
                           privileged_classes=privileged_classes)

# Preprocessing the data
X = train_df.drop('Type', axis=1)
y = train_df['Type']

y_pred_6 = pd.Series(0, index=X.index)

scores = []

for train_index, test_index in StratifiedKFold(n_splits=5).split(X.values, y.values):
    X_Train, X_Test = X.values[train_index], X.values[test_index]
    y_Train, y_Test = y.iloc[train_index], y.iloc[test_index]

    # Train your model on the original data
    model.fit(X_Train, y_Train)
    
    # Make predictions on the training and test sets
    y_train_pred = model.predict(X_Train)
    y_test_pred = model.predict(X_Test)
    
    # Combine predictions with training data
    combined_train = pd.DataFrame(X_Train, columns=X.columns)
    combined_train['Type'] = y_Train.values
    combined_train['pred'] = y_train_pred
    combined_train['scores'] = model.predict_proba(X_Train)[:, 1]  # Get probability scores

    # Convert to AIF360 format for the training set
    aif360_train = convert_to_dataset(combined_train,
                                      label_name='Type', favorable_classes=[1],
                                      protected_attribute_names=['Patient Gender'],
                                      privileged_classes=[[1]])
    
    # Convert to AIF360 format for the predicted training set
    combined_train_pred = combined_train.copy()
    combined_train_pred['Type'] = combined_train['pred']
    aif360_train_pred = convert_to_dataset(combined_train_pred,
                                           label_name='Type', favorable_classes=[1],
                                           protected_attribute_names=['Patient Gender'],
                                           privileged_classes=[[1]])
    
    # Apply Reject Option Classification using only the training set
    roc = RejectOptionClassification(privileged_groups=[{'Patient Gender': 1}],
                                     unprivileged_groups=[{'Patient Gender': 0}],
                                     low_class_thresh=0.01, high_class_thresh=0.99,
                                     num_class_thresh=100, num_ROC_margin=50, metric_name="Average odds difference")
    roc = roc.fit(aif360_train, aif360_train_pred)
    
    # Apply the post-processing to the test predictions
    combined_test = pd.DataFrame(X_Test, columns=X.columns)
    combined_test['pred'] = y_test_pred
    combined_test['scores'] = model.predict_proba(X_Test)[:, 1]  # Get probability scores
    aif360_test_pred = convert_to_dataset(combined_test,
                                          label_name='pred', favorable_classes=[1],
                                          protected_attribute_names=['Patient Gender'],
                                          privileged_classes=[[1]])
    
    aif360_test_pred = roc.predict(aif360_test_pred)
    
    # Get the final predictions
    preds = aif360_test_pred.labels.ravel()
    y_pred_6[test_index] = preds

    scores.append(accuracy_score(y_Test.values, preds))
    print(scores[-1])

print("Mean:", np.mean(scores), "\nSTD: ", np.std(scores), '\n')
# Out:
# 0.9705800721620872
# 0.9752983624757147
# 0.9758534554537885
# 0.9691923397169026
# 0.9733555370524563
# Mean: 0.9728559533721898
# STD:  0.0026000640418829615

# %%
y_pred_6.to_csv('y_pred_ROC.csv',index=False)

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf

for age_cls in range(2):
    for priv_cls in [0,1]:
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Patient Gender'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_6

        import numpy as np

        # Define the groups
        groups = [
            {'Patient Gender': 0},
            {'Patient Gender': 1}
        ]



        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.03297033790725762
# Max Average Odds Difference (Ideal value = 0): 0.009108036651532987
# Max Equal Opportunity Difference (Ideal value = 0): 0.010906694715780985
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832

# %%
import pandas as pd
import numpy as np

# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls in range(7):
        # Convert to AIF360 format
        aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                         label_name='Type', favorable_classes=[age_cls],
                                         protected_attribute_names=['Age Range'],
                                         privileged_classes=[[priv_cls]])

        # Create a dataset for the predictions
        aif360_pred_dataset = aif360_dataset.copy()
        aif360_pred_dataset.labels = y_pred_6

        import numpy as np

        # Define the groups
        groups = [
            {'Age Range': 0},
            {'Age Range': 1},
            {'Age Range': 2},
            {'Age Range': 3},
            {'Age Range': 4},
            {'Age Range': 5},
            {'Age Range': 6}]


        # Iterate through the groups
        for i, privileged_group in enumerate(groups):
            # Define unprivileged groups as all other groups
            unprivileged_groups = groups[:i] + groups[i+1:]

            # Calculate metrics
            metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                          unprivileged_groups=unprivileged_groups,
                                          privileged_groups=[privileged_group])

            # Update maximum values
            max_spd = max(max_spd, metric.statistical_parity_difference())
            max_aod = max(max_aod, metric.average_odds_difference())
            max_eod = max(max_eod, metric.equal_opportunity_difference())
            max_theil = max(max_theil, metric.theil_index())
            max_gei = max(max_gei, metric.generalized_entropy_index())
            max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.1967133484268908
# Max Average Odds Difference (Ideal value = 0): 0.037805277305967736
# Max Equal Opportunity Difference (Ideal value = 0): 0.056533447407729476
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832

# %%
import pandas as pd
import numpy as np


# Initialize variables to store maximum values of each metric
max_spd = max_aod = max_eod = max_theil = max_gei = max_di = -np.inf


# Find Max value for metrics by looping into all unique_values for the target and for the privileged class
for age_cls in range(2):
    for priv_cls_1 in [0,1]:   # Gender        
        for priv_cls_2 in range(7):   # Ethnicity

            # Convert to AIF360 format
            aif360_dataset = StandardDataset(df=pd.concat([X, y], axis=1),
                                             label_name='Type', favorable_classes=[age_cls],
                                             protected_attribute_names=['Patient Gender','Age Range'],
                                             privileged_classes=[[priv_cls_1], [priv_cls_2]])

            # Create a dataset for the predictions
            aif360_pred_dataset = aif360_dataset.copy()
            aif360_pred_dataset.labels = y_pred_6

            import numpy as np

            # Define the groups
            groups = [{'Patient Gender':0, 'Age Range':i} for i in range(7)] + [{'Patient Gender':1, 'Age Range':i} for i in range(7)] 

            # Iterate through the groups
            for i, privileged_group in enumerate(groups):
                # Define unprivileged groups as all other groups
                unprivileged_groups = groups[:i] + groups[i+1:]

                # Calculate metrics
                metric = ClassificationMetric(aif360_dataset, aif360_pred_dataset,
                                              unprivileged_groups=unprivileged_groups,
                                              privileged_groups=[privileged_group])

                # Update maximum values
                max_spd = max(max_spd, metric.statistical_parity_difference())
                max_aod = max(max_aod, metric.average_odds_difference())
                max_eod = max(max_eod, metric.equal_opportunity_difference())
                max_theil = max(max_theil, metric.theil_index())
                max_gei = max(max_gei, metric.generalized_entropy_index())
                max_di = max(max_di, metric.disparate_impact())

# Print maximum values
print("Gender+Ethnicity Bias Identification:")
print("Max Statistical Parity Difference (Ideal value = 0):", max_spd)
print("Max Average Odds Difference (Ideal value = 0):", max_aod)
print("Max Equal Opportunity Difference (Ideal value = 0):", max_eod)
print("Max Theil Index (Ideal value = 0):", max_theil)
print("Max Generalized Entropy Index (Ideal value = 0):", max_gei)
# Out:
# Gender+Ethnicity Bias Identification:
# Max Statistical Parity Difference (Ideal value = 0): 0.19795889853009152
# Max Average Odds Difference (Ideal value = 0): 0.060817638109360764
# Max Equal Opportunity Difference (Ideal value = 0): 0.1043470980854061
# Max Theil Index (Ideal value = 0): 0.018832896433778702
# Max Generalized Entropy Index (Ideal value = 0): 0.013573528645527832
